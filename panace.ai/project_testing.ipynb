# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv('C:\\datascience\\nutrition.csv')
print(df1)
df1.info()
# Out:
#       Unnamed: 0                                               name  \
# 0              0                                         Cornstarch
# 1              1                                       Nuts, pecans
# 2              2                                      Eggplant, raw
# 3              3                                     Teff, uncooked
# 4              4                                    Sherbet, orange
# ...          ...                                                ...
# 8784        8784  Beef, raw, all grades, trimmed to 0" fat, sepa...
# 8785        8785  Lamb, cooked, separable lean only, composite o...
# 8786        8786  Lamb, raw, separable lean and fat, composite o...
# 8787        8787  Beef, raw, all grades, trimmed to 0" fat, sepa...
# 8788        8788  Beef, raw, all grades, trimmed to 0" fat, sepa...
#
#      serving_size  calories total_fat saturated_fat cholesterol    sodium  \
# 0           100 g       381      0.1g           NaN           0   9.00 mg
# ...

# %%
df2=pd.read_csv('C:\\datascience\\Groceries_dataset.csv')
df2
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
print(df1.shape)
print(df2.shape)
# Out:
# (8789, 77)
# (38765, 3)

# %%
len(df1.name.unique()),len(df2.itemDescription.unique()),len(df2.Member_number.unique())
# Out:
# (8789, 167, 3898)

# %%
df2.sort_values(by='Member_number',inplace=True)

# %%
print(df2['Member_number'].value_counts())
print(df2['itemDescription'].value_counts())
plt.figure(figsize=(15,30))
df2['itemDescription'].value_counts().plot(kind='barh')
plt.show()
# Out:
# 3180    36
# 3737    33
# 3050    33
# 2051    33
# 3915    31
#         ..
# 3533     2
# 2302     2
# 4824     2
# 1084     2
# 3377     2
# Name: Member_number, Length: 3898, dtype: int64
# whole milk               2502
# other vegetables         1898
# rolls/buns               1716
# soda                     1514
# yogurt                   1334
#                          ...
# make up remover             5
# bags                        4
# baby cosmetics              3
# kitchen utensil             1
# preservation products       1
# Name: itemDescription, Length: 167, dtype: int64

# %%
plt.figure(figsize=(15,30))
df2['Member_number'].value_counts().plot(kind='barh')
plt.show()

# %%
df1.isnull().sum()
df1['saturated_fat']=df1['saturated_fat'].replace(np.nan,0)
df1.info()
df1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8789 entries, 0 to 8788
# Data columns (total 77 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   8789 non-null   int64
#  1   name                         8789 non-null   object
#  2   serving_size                 8789 non-null   object
#  3   calories                     8789 non-null   int64
#  4   total_fat                    8789 non-null   object
#  5   saturated_fat                8789 non-null   object
#  6   cholesterol                  8789 non-null   object
#  7   sodium                       8789 non-null   object
#  8   choline                      8789 non-null   object
#  9   folate                       8789 non-null   object
#  10  folic_acid                   8789 non-null   object
#  11  niacin                       8789 non-null   object
#  12  pantothenic_acid             8789 non-null   object
# ...

# %%
x=df1['name']=='Cornstarch'
dup=pd.DataFrame(df1.loc[df1['name']=='Eggplant, raw'].values)
dup.columns=df1.columns
dup
# Out:
#   Unnamed: 0           name serving_size calories total_fat saturated_fat  \
# 0          2  Eggplant, raw        100 g       25      0.2g             0
#
#   cholesterol   sodium choline     folate  ...     fat saturated_fatty_acids  \
# 0           0  2.00 mg  6.9 mg  22.00 mcg  ...  0.18 g               0.034 g
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                     0.016 g                     0.076 g
#
#   fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# 0                 0.00 mg   0.0 g  0.66 g  0.00 mg     0.00 mg  92.30 g
#
# [1 rows x 77 columns]

# %%
dup1=df1["name"].str.contains("Tropical fruit").values
temp=[]
for i in range (len(dup1)):
    if dup1[i]==True:
        temp.append(i)
temp
# Out:
# [6607]

# %%
l=dup1[dup1['present']==True].index
l

# %%
df1.columns
df1=df1[['name', 'serving_size', 'calories', 'total_fat',
       'saturated_fat', 'cholesterol', 'sodium', 'choline', 'folate',
       'folic_acid', 'niacin', 'pantothenic_acid', 'riboflavin', 'thiamin',
       'vitamin_a', 'vitamin_a_rae', 'carotene_alpha', 'carotene_beta',
       'cryptoxanthin_beta', 'lutein_zeaxanthin', 'lucopene', 'vitamin_b12',
       'vitamin_b6', 'vitamin_c', 'vitamin_d', 'vitamin_e', 'tocopherol_alpha',
       'vitamin_k', 'calcium', 'copper', 'irom', 'magnesium', 'manganese',
       'phosphorous', 'potassium', 'selenium', 'zink', 'protein', 'alanine',
       'arginine', 'aspartic_acid', 'cystine', 'glutamic_acid', 'glycine',
       'histidine', 'hydroxyproline', 'isoleucine', 'leucine', 'lysine',
       'methionine', 'phenylalanine', 'proline', 'serine', 'threonine',
       'tryptophan', 'tyrosine', 'valine', 'carbohydrate', 'fiber', 'sugars',
       'fructose', 'galactose', 'glucose', 'lactose', 'maltose', 'sucrose',
       'fat', 'saturated_fatty_acids', 'monounsaturated_fatty_acids',
       'polyunsaturated_fatty_acids', 'fatty_acids_total_trans', 'alcohol',
       'ash', 'caffeine', 'theobromine', 'water']]
df1
# Out:
#                                                    name serving_size  \
# 0                                            Cornstarch        100 g
# 1                                          Nuts, pecans        100 g
# 2                                         Eggplant, raw        100 g
# 3                                        Teff, uncooked        100 g
# 4                                       Sherbet, orange        100 g
# ...                                                 ...          ...
# 8784  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8785  Lamb, cooked, separable lean only, composite o...        100 g
# 8786  Lamb, raw, separable lean and fat, composite o...        100 g
# 8787  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8788  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
#
#       calories total_fat saturated_fat cholesterol    sodium  choline  \
# ...

# %%
print(len(temp))
for i in temp:
    print(pd.DataFrame(df1.loc[i].values,index=df1.columns))
# Out:
# 1
#                                                                0
# name           Candies, Tropical fruits, STARBURST Fruit Chew...
# serving_size                                               100 g
# calories                                                     409
# total_fat                                                   8.3g
# saturated_fat                                                 8g
# ...                                                          ...
# alcohol                                                        0
# ash                                                       0.30 g
# caffeine                                                       0
# theobromine                                                    0
# water                                                     8.51 g
#
# [76 rows x 1 columns]

# %%
df1
# Out:
#                                                    name serving_size  \
# 0                                            Cornstarch        100 g
# 1                                          Nuts, pecans        100 g
# 2                                         Eggplant, raw        100 g
# 3                                        Teff, uncooked        100 g
# 4                                       Sherbet, orange        100 g
# ...                                                 ...          ...
# 8784  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8785  Lamb, cooked, separable lean only, composite o...        100 g
# 8786  Lamb, raw, separable lean and fat, composite o...        100 g
# 8787  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8788  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
#
#       calories total_fat saturated_fat cholesterol    sodium  choline  \
# ...

# %%
df1.to_csv('Nutrition.csv',index=False)

# %%
df2
# Out:
#        Member_number        Date      itemDescription
# 1629            1000  27-05-2015                 soda
# 13331           1000  24-06-2014           whole milk
# 8395            1000  15-03-2015           whole milk
# 4843            1000  15-03-2015              sausage
# 17778           1000  27-05-2015   pickled vegetables
# ...              ...         ...                  ...
# 34885           5000  10-02-2015  semi-finished bread
# 25489           5000  16-11-2014     other vegetables
# 9340            5000  16-11-2014         bottled beer
# 27877           5000  09-03-2014               onions
# 3578            5000  10-02-2015                 soda
#
# [38765 rows x 3 columns]

# %%
dft=df2['itemDescription'].str.split('/',expand=True).rename(columns={0:'Item',1:'Item-2'})
dft
# df2=pd.concat(['df2','dft'],axis=1)
dft.info()
dft.drop(['Item-2'],inplace=True,axis=1)
dft=pd.DataFrame(dft)
dft
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38765 entries, 1629 to 3578
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Item    38765 non-null  object
#  1   Item-2  3383 non-null   object
# dtypes: object(2)
# memory usage: 1.9+ MB
#                       Item
# 1629                  soda
# 13331           whole milk
# 8395            whole milk
# 4843               sausage
# 17778   pickled vegetables
# ...                    ...
# 34885  semi-finished bread
# 25489     other vegetables
# 9340          bottled beer
# 27877               onions
# 3578                  soda
#
# [38765 rows x 1 columns]

# %%
df2.drop(['itemDescription'],axis=1,inplace=True)

# %%
df2
# Out:
#        Member_number        Date
# 1629            1000  27-05-2015
# 13331           1000  24-06-2014
# 8395            1000  15-03-2015
# 4843            1000  15-03-2015
# 17778           1000  27-05-2015
# ...              ...         ...
# 34885           5000  10-02-2015
# 25489           5000  16-11-2014
# 9340            5000  16-11-2014
# 27877           5000  09-03-2014
# 3578            5000  10-02-2015
#
# [38765 rows x 2 columns]

# %%
dft['Member_number']=df2['Member_number'].values
dft['Date']=df2['Date'].values
dft
# Out:
#                       Item  Member_number        Date
# 1629                  soda           1000  27-05-2015
# 13331           whole milk           1000  24-06-2014
# 8395            whole milk           1000  15-03-2015
# 4843               sausage           1000  15-03-2015
# 17778   pickled vegetables           1000  27-05-2015
# ...                    ...            ...         ...
# 34885  semi-finished bread           5000  10-02-2015
# 25489     other vegetables           5000  16-11-2014
# 9340          bottled beer           5000  16-11-2014
# 27877               onions           5000  09-03-2014
# 3578                  soda           5000  10-02-2015
#
# [38765 rows x 3 columns]

# %%
dft=dft.loc[:,['Member_number','Date','Item']]
d
# Out:
#        Member_number        Date                 Item
# 1629            1000  27-05-2015                 soda
# 13331           1000  24-06-2014           whole milk
# 8395            1000  15-03-2015           whole milk
# 4843            1000  15-03-2015              sausage
# 17778           1000  27-05-2015   pickled vegetables
# ...              ...         ...                  ...
# 34885           5000  10-02-2015  semi-finished bread
# 25489           5000  16-11-2014     other vegetables
# 9340            5000  16-11-2014         bottled beer
# 27877           5000  09-03-2014               onions
# 3578            5000  10-02-2015                 soda
#
# [38765 rows x 3 columns]

# %%
dft.to_csv('Groceries.csv',index=False)
